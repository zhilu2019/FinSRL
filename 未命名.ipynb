# %%
import datetime
import pandas as pd
import numpy as np

from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl.meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL")

import itertools

import wandb
wandb.login(key="fd2d0476c22a97c32eef81b22402a4c73ab32831")


from finrl import config
from finrl import config_tickers
import os
#os.environ["CUDA_VISIBLE_DEVICES"]="0"

from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])


#超参数优化

sweep_config = {
    'method': 'random'
    }

import math
parameters_dict = {
    'n_steps':{
        'values':[2048, 256, 128,512,1024,4098]
        },
    'total_timesteps':{
        'values':[50000, 100000, 200000,300000,500000]
        },
    'ent_coef': {
                'distribution': 'uniform',
        'min': 0,
        'max': 0.1
        },
    'learning_rate': {
        # a flat distribution between 0 and 0.1
        'distribution': 'uniform',
        'min': 0,
        'max': 0.1
      },
    'batch_size': {
        # integers between 32 and 256
        # with evenly-distributed logarithms 
        'distribution': 'q_log_uniform',
        'q': 1,
        'min': math.log(32),
        'max': math.log(1024),
      }
    }

sweep_config['parameters'] = parameters_dict








TRAIN_START_DATE = '2008-01-01'
TRAIN_END_DATE = '2020-03-01'
TRADE_START_DATE = '2020-03-01'
TRADE_END_DATE = '2022-10-10'


res = pd.read_csv('DOW_8s.csv')   #读取整理好后数据，根据情况进行时间格式转换
#INDICATORS.pop()
INDICATORS
INDICATORS.append('sentiment_score')


#时间格式转换
res['date'] = pd.to_datetime(res['date'],errors='coerce')     #str转date
res['date'] = res['date'].dt.strftime('%Y-%m-%d')   #date转str


train = data_split(res, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(res, TRADE_START_DATE,TRADE_END_DATE)


#建议环境配置
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")

buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 20,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)


#设置train环境
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
sweep_id = wandb.sweep(sweep_config, project="test-project")


def train():
    wandb.init()
    agent = DRLAgent(env = env_train)
    PPO_PARAMS = {
            "ent_coef": wandb.config.ent_coef,
            "n_steps": wandb.config.n_steps,
            "learning_rate": wandb.config.learning_rate,
            "batch_size": wandb.config.batch_size,}


    model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)




    trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=wandb.config.total_timesteps)




    #Set turbulence threshold
    data_risk_indicator = res[(res.date<TRAIN_END_DATE) & (res.date>=TRAIN_START_DATE)]
    insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])
    insample_risk_indicator.vix.describe() #VIX
    insample_risk_indicator.vix.quantile(0.996)
    insample_risk_indicator.turbulence.describe() #turbulence
    insample_risk_indicator.turbulence.quantile(0.996)



    e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)
    trained_moedl = trained_ppo
    df_account_value, df_actions = DRLAgent.DRL_prediction(
    model=trained_moedl, 
    environment = e_trade_gym)
    #df_account_value.shape #资产格式
    #print(df_account_value.tail()) #资产状态
    #df_actions.tail(200)    #交易操作



    print("==============Get Backtest Results===========")
    now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

    perf_stats_all = backtest_stats(account_value=df_account_value)
    perf_stats_all = pd.DataFrame(perf_stats_all)



    wandb.log({"Backtest Results": perf_stats_all,
          "action": df_actions,})
    
    
wandb.agent(sweep_id, train, count=50)

wandb.finish()
# Out:
# /Users/zhangzhilu/opt/anaconda3/envs/finrl/lib/python3.7/site-packages/pyfolio/pos.py:27: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; mutltipliers will not be applied' +
# wandb: Currently logged in as: zhilu (finsrl). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /Users/zhangzhilu/.netrc
#              date   tic        open        high         low       close  \
# 0      2008-01-02  AAPL    7.116786    7.152143    6.876786    5.931611
# 1      2008-01-02   CAT   72.559998   72.669998   70.050003   46.539093
# 2      2008-01-02   DIS   32.320000   32.630001   31.690001   27.012506
# 3      2008-01-02    GS  214.800003  215.050003  206.600006  166.547913
# 4      2008-01-02  INTC   26.280001   26.340000   24.950001   16.023220
# ...           ...   ...         ...         ...         ...         ...
# 24483  2020-02-28    GS  199.089996  202.250000  194.850006  190.099899
# 24484  2020-02-28  INTC   54.299999   56.380001   53.599998   51.038109
# 24485  2020-02-28   JPM  117.519997  118.489998  112.660004  106.632568
# 24486  2020-02-28   MMM  154.089996  156.720001  146.000000  136.575607
# 24487  2020-02-28  MSFT  152.410004  163.710007  152.000000  158.378555
#
#              volume  day      macd     boll_ub     boll_lb      rsi_30  \
# 0      1.079179e+09  2.0  0.000000    5.936854    5.929106  100.000000
# 1      6.337800e+06  2.0  0.000000    5.936854    5.929106  100.000000
# 2      9.269900e+06  2.0  0.000000    5.936854    5.929106  100.000000
# 3      9.573500e+06  2.0  0.000000    5.936854    5.929106  100.000000
# 4      8.427880e+07  2.0  0.000000    5.936854    5.929106  100.000000
# ...             ...  ...       ...         ...         ...         ...
# 24483  6.727100e+06  4.0 -6.884721  240.599196  195.151454   33.198642
# 24484  6.072170e+07  4.0 -1.148541   65.999451   52.079523   39.631347
# 24485  4.593140e+07  4.0 -3.044945  134.112050  111.226425   31.147776
# 24486  1.149970e+07  4.0 -4.518615  151.950653  134.805834   37.130619
# 24487  9.701270e+07  4.0 -0.546872  191.139309  156.875584   46.929765
#
#            cci_30       dx_30  close_30_sma  close_60_sma        vix  \
# 0      -66.666667  100.000000      5.931611      5.931611  23.170000
# 1      -66.666667  100.000000     46.539093     46.539093  23.170000
# 2      -66.666667  100.000000     27.012506     27.012506  23.170000
# 3      -66.666667  100.000000    166.547913    166.547913  23.170000
# 4      -66.666667  100.000000     16.023220     16.023220  23.170000
# ...           ...         ...           ...           ...        ...
# 24483 -299.716473   70.646864    221.931034    219.330971  40.110001
# 24484 -209.798016   49.175170     58.878703     56.159310  40.110001
# 24485 -360.952926   71.946842    123.266790    124.170060  40.110001
# 24486 -109.706356   42.150649    148.229326    153.161724  40.110001
# 24487 -120.306870   45.243390    170.138823    161.376249  40.110001
#
#        turbulence  sentiment_score
# 0        0.000000         0.000000
# 1        0.000000         0.000000
# 2        0.000000         0.000000
# 3        0.000000         0.000000
# 4        0.000000         0.000000
# ...           ...              ...
# 24483   46.131081        -0.633918
# 24484   46.131081         0.000000
# 24485   46.131081        -0.918611
# 24486   46.131081         0.000000
# 24487   46.131081        -0.920729
#
# [24488 rows x 19 columns]
#              date   tic        open        high         low       close  \
# 24488  2020-03-02  AAPL   70.570000   75.360001   69.430000   73.358047
# 24489  2020-03-02   CAT  125.050003  127.879997  123.010002  119.378723
# 24490  2020-03-02   DIS  119.129997  119.980003  116.029999  119.980003
# 24491  2020-03-02    GS  201.410004  209.619995  197.630005  198.337524
# 24492  2020-03-02  INTC   55.790001   58.220001   54.520000   53.483379
# ...           ...   ...         ...         ...         ...         ...
# 28195  2021-12-30    GS  387.750000  389.779999  385.200012  378.073547
# 28196  2021-12-30  INTC   51.919998   52.139999   51.650002   49.764824
# 28197  2021-12-30   JPM  159.110001  160.240005  158.369995  153.630920
# 28198  2021-12-30   MMM  178.869995  179.179993  177.580002  172.409698
# 28199  2021-12-30  MSFT  341.910004  343.130005  338.820007  337.117401
#
#             volume  day      macd     boll_ub     boll_lb     rsi_30  \
# 24488  341397200.0  0.0 -1.505155   84.623472   67.830785  50.471433
# 24489    6100200.0  0.0 -3.313555  134.247803  115.667258  40.784470
# 24490   21775900.0  0.0 -5.610321  153.938308  117.765691  33.116996
# 24491    5285500.0  0.0 -7.226576  240.743740  192.466014  39.512968
# 24492   43140300.0  0.0 -1.301557   66.179559   51.399631  44.890571
# ...            ...  ...       ...         ...         ...        ...
# 28195    1160100.0  3.0 -2.340111  393.415306  366.984059  47.980519
# 28196   18359400.0  3.0  0.336166   50.671579   47.133511  51.864768
# 28197    6948200.0  3.0 -1.387393  157.681036  149.930779  46.863478
# 28198    1067300.0  3.0 -0.076721  174.545485  165.865664  49.461085
# 28199   15994500.0  3.0  2.474487  344.702493  316.514389  56.610900
#
#            cci_30      dx_30  close_30_sma  close_60_sma        vix  \
# 24488 -122.318026  24.696060     76.737905     73.713963  33.419998
# 24489 -151.591695  35.844375    126.789064    131.320238  33.419998
# 24490 -222.545386  59.386263    137.255665    141.561159  33.419998
# 24491 -206.953430  48.509882    220.708569    219.307613  33.419998
# 24492 -160.362113  34.330512     58.842311     56.195847  33.419998
# ...           ...        ...           ...           ...        ...
# 28195  -22.639922   8.295442    380.526413    387.899763  17.330000
# 28196  111.860232  19.265569     48.462189     48.920246  17.330000
# 28197  -34.426013   0.338797    155.140613    159.130352  17.330000
# 28198   61.933906   6.777908    170.705090    172.272548  17.330000
# 28199   79.693437  17.764937    331.874005    323.465860  17.330000
#
#        turbulence  sentiment_score
# 24488   45.282055        -0.865518
# 24489   45.282055         0.000000
# 24490   45.282055         0.759892
# 24491   45.282055        -0.892112
# 24492   45.282055        -0.820277
# ...           ...              ...
# 28195    1.631790        -0.702486
# 28196    1.631790         0.000000
# 28197    1.631790        -0.286425
# 28198    1.631790         0.000000
# 28199    1.631790        -0.954623
#
# [3712 rows x 19 columns]
# Stock Dimension: 8, State Space: 89
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>
# wandb: WARNING Malformed sweep config detected! This may cause your sweep to behave in unexpected ways.
# wandb: WARNING To avoid this, please fix the sweep config schema violations below:
# wandb: WARNING   Violation 1. batch_size uses q_log_uniform, where min/max specify base-e exponents. Use q_log_uniform_values to specify limit values.
# Create sweep with ID: wjkvqlsd
# Sweep URL: https://wandb.ai/finsrl/test-project/sweeps/wjkvqlsd
# wandb: Agent Starting Run: ufb9b2fs with config:
# wandb: 	batch_size: 556
# wandb: 	ent_coef: 0.010850762418435711
# wandb: 	learning_rate: 0.04205927886524091
# wandb: 	n_steps: 128
# wandb: 	total_timesteps: 300000
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016753713199999964, max=1.0…
# Tracking run with wandb version 0.13.6
# Run data is saved locally in <code>/Users/zhangzhilu/Desktop/投资组合代码/FinRL-master/wandb/run-20221212_173357-ufb9b2fs</code>
# Syncing run <strong><a href="https://wandb.ai/finsrl/test-project/runs/ufb9b2fs" target="_blank">wild-sweep-1</a></strong> to <a href="https://wandb.ai/finsrl/test-project" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/finsrl/test-project/sweeps/wjkvqlsd" target="_blank">https://wandb.ai/finsrl/test-project/sweeps/wjkvqlsd</a>
# {'ent_coef': 0.010850762418435711, 'n_steps': 128, 'learning_rate': 0.04205927886524091, 'batch_size': 556}
# Using cpu device
# /Users/zhangzhilu/opt/anaconda3/envs/finrl/lib/python3.7/site-packages/stable_baselines3/ppo/ppo.py:154: UserWarning: You have specified a mini-batch size of 556, but because the `RolloutBuffer` is of size `n_steps * n_envs = 128`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 128
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=128 and n_envs=1)
#   f"You have specified a mini-batch size of {batch_size},"
# ------------------------------------
# | time/              |             |
# |    fps             | 85          |
# |    iterations      | 1           |
# |    time_elapsed    | 1           |
# |    total_timesteps | 128         |
# | train/             |             |
# |    reward          | -0.13082159 |
# ------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 2          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 256        |
# | train/                  |            |
# |    approx_kl            | 3.4071157  |
# |    clip_fraction        | 0.848      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -11.9      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0421     |
# |    loss                 | 0.364      |
# |    n_updates            | 10         |
# |    policy_gradient_loss | 0.19       |
# |    reward               | -0.6660549 |
# |    std                  | 1.16       |
# |    value_loss           | 6.44       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 84        |
# |    iterations           | 3         |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 384       |
# | train/                  |           |
# |    approx_kl            | 3.1002662 |
# |    clip_fraction        | 0.873     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0421    |
# |    loss                 | 0.372     |
# |    n_updates            | 20        |
# |    policy_gradient_loss | 0.21      |
# |    reward               | 0.9918867 |
# |    std                  | 1.36      |
# |    value_loss           | 0.576     |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 93         |
# |    iterations           | 4          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 512        |
# | train/                  |            |
# |    approx_kl            | 0.44570738 |
# |    clip_fraction        | 0.762      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -13.6      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0421     |
# |    loss                 | 0.768      |
# |    n_updates            | 30         |
# |    policy_gradient_loss | 0.157      |
# |    reward               | 0.3295541  |
# |    std                  | 1.43       |
# |    value_loss           | 1.57       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 5          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 640        |
# | train/                  |            |
# |    approx_kl            | 5.1559196  |
# |    clip_fraction        | 0.859      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -13.8      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0421     |
# |    loss                 | 0.852      |
# |    n_updates            | 40         |
# |    policy_gradient_loss | 0.186      |
# |    reward               | 0.11994724 |
# |    std                  | 1.53       |
# |    value_loss           | 1.71       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 6          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 768        |
# | train/                  |            |
# |    approx_kl            | 1.8704122  |
# |    clip_fraction        | 0.857      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.1      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0421     |
# |    loss                 | 1.5        |
# |    n_updates            | 50         |
# |    policy_gradient_loss | 0.173      |
# |    reward               | -0.7976266 |
# |    std                  | 1.6        |
# |    value_loss           | 3.01       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 103        |
# |    iterations           | 7          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 896        |
# | train/                  |            |
# |    approx_kl            | 0.81507355 |
# |    clip_fraction        | 0.819      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.6      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0421     |
# |    loss                 | 0.627      |
# |    n_updates            | 60         |
# |    policy_gradient_loss | 0.12       |
# |    reward               | 0.22740123 |
# |    std                  | 1.68       |
# |    value_loss           | 1.6        |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 106       |
# |    iterations           | 8         |
# |    time_elapsed         | 9         |
# |    total_timesteps      | 1024      |
# | train/                  |           |
# |    approx_kl            | 1.4199078 |
# |    clip_fraction        | 0.827     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0421    |
# |    loss                 | 1.4       |
# |    n_updates            | 70        |
# |    policy_gradient_loss | 0.143     |
# |    reward               | 0.904213  |
# |    std                  | 1.73      |
# |    value_loss           | 2.51      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 106       |
# |    iterations           | 9         |
# |    time_elapsed         | 10        |
# |    total_timesteps      | 1152      |
# | train/                  |           |
# |    approx_kl            | 0.2434112 |
# |    clip_fraction        | 0.661     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -15.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0421    |
# |    loss                 | 4.91      |
# |    n_updates            | 80        |
# |    policy_gradient_loss | 0.0634    |
# |    reward               | 2.128638  |
# |    std                  | 1.91      |
# |    value_loss           | 9.98      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 110       |
# |    iterations           | 10        |
# |    time_elapsed         | 11        |
# |    total_timesteps      | 1280      |
# | train/                  |           |
# |    approx_kl            | 0.5630285 |
# |    clip_fraction        | 0.803     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -16       |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0421    |
# |    loss                 | 10        |
# |    n_updates            | 90        |
# |    policy_gradient_loss | 0.104     |
# |    reward               | 1.4133475 |
# |    std                  | 2.12      |
# |    value_loss           | 20.3      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 114        |
# |    iterations           | 11         |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 1408       |
# | train/                  |            |
# |    approx_kl            | 0.8293497  |
# |    clip_fraction        | 0.745      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -16.9      |
# |    explained_variance   | -1.91e-06  |
# |    learning_rate        | 0.0421     |
# |    loss                 | 3.16       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | 0.141      |
# |    reward               | -1.1024468 |
# |    std                  | 2.45       |
# |    value_loss           | 6.41       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 117       |
# |    iterations           | 12        |
# |    time_elapsed         | 13        |
# |    total_timesteps      | 1536      |
# | train/                  |           |
# |    approx_kl            | 0.3106264 |
# |    clip_fraction        | 0.759     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -17.7     |
# |    explained_variance   | 3.22e-06  |
# |    learning_rate        | 0.0421    |
# |    loss                 | 3.75      |
# |    n_updates            | 110       |
# |    policy_gradient_loss | 0.224     |
# |    reward               | 0.743117  |
# |    std                  | 2.55      |
# |    value_loss           | 8.55      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 13         |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 1664       |
# | train/                  |            |
# |    approx_kl            | 7.017308   |
# |    clip_fraction        | 0.877      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -17.9      |
# |    explained_variance   | -0.447     |
# |    learning_rate        | 0.0421     |
# |    loss                 | 5.92       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | 0.349      |
# |    reward               | 0.04296286 |
# |    std                  | 2.69       |
# |    value_loss           | 13.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 123        |
# |    iterations           | 14         |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 1792       |
# | train/                  |            |
# |    approx_kl            | 1.0391191  |
# |    clip_fraction        | 0.689      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -18.4      |
# |    explained_variance   | -0.000574  |
# |    learning_rate        | 0.0421     |
# |    loss                 | 6.32       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | 0.0688     |
# |    reward               | 0.53177154 |
# |    std                  | 2.89       |
# |    value_loss           | 13.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 15          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 1920        |
# | train/                  |             |
# |    approx_kl            | 0.17883767  |
# |    clip_fraction        | 0.703       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18.8       |
# |    explained_variance   | -0.000166   |
# |    learning_rate        | 0.0421      |
# |    loss                 | 12.2        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.104       |
# |    reward               | -0.17849018 |
# |    std                  | 3.01        |
# |    value_loss           | 25.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 126        |
# |    iterations           | 16         |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 2048       |
# | train/                  |            |
# |    approx_kl            | 0.09142396 |
# |    clip_fraction        | 0.512      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -18.9      |
# |    explained_variance   | -2.93e-05  |
# |    learning_rate        | 0.0421     |
# |    loss                 | 7.65       |
# |    n_updates            | 150        |
# |    policy_gradient_loss | 0.036      |
# |    reward               | 2.3423886  |
# |    std                  | 3.04       |
# |    value_loss           | 16.4       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 128          |
# |    iterations           | 17           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 2176         |
# | train/                  |              |
# |    approx_kl            | 0.3773       |
# |    clip_fraction        | 0.617        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -18.8        |
# |    explained_variance   | -0.000431    |
# |    learning_rate        | 0.0421       |
# |    loss                 | 33.6         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.0966       |
# |    reward               | -0.025793053 |
# |    std                  | 2.91         |
# |    value_loss           | 69.1         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 130        |
# |    iterations           | 18         |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 2304       |
# | train/                  |            |
# |    approx_kl            | 0.11329132 |
# |    clip_fraction        | 0.655      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -18.6      |
# |    explained_variance   | 8.34e-07   |
# |    learning_rate        | 0.0421     |
# |    loss                 | 11         |
# |    n_updates            | 170        |
# |    policy_gradient_loss | 0.0741     |
# |    reward               | 0.2970006  |
# |    std                  | 2.79       |
# |    value_loss           | 24.6       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 129       |
# |    iterations           | 19        |
# |    time_elapsed         | 18        |
# |    total_timesteps      | 2432      |
# | train/                  |           |
# |    approx_kl            | 1.5696534 |
# |    clip_fraction        | 0.758     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -18.5     |
# |    explained_variance   | -3.99e-05 |
# |    learning_rate        | 0.0421    |
# |    loss                 | 34.4      |
# |    n_updates            | 180       |
# |    policy_gradient_loss | 0.185     |
# |    reward               | -1.453905 |
# |    std                  | 2.77      |
# |    value_loss           | 121       |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 127        |
# |    iterations           | 20         |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 2560       |
# | train/                  |            |
# |    approx_kl            | 0.21057631 |
# |    clip_fraction        | 0.634      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -18.6      |
# |    explained_variance   | 0.000127   |
# |    learning_rate        | 0.0421     |
# |    loss                 | 22.7       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | 0.0141     |
# |    reward               | 5.5480523  |
# |    std                  | 2.82       |
# |    value_loss           | 49.1       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 130        |
# |    iterations           | 21         |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 2688       |
# | train/                  |            |
# |    approx_kl            | 0.6803792  |
# |    clip_fraction        | 0.735      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -18.7      |
# |    explained_variance   | 1.49e-06   |
# |    learning_rate        | 0.0421     |
# |    loss                 | 29.9       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | 0.19       |
# |    reward               | -1.8303922 |
# |    std                  | 2.87       |
# |    value_loss           | 101        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 132        |
# |    iterations           | 22         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 2816       |
# | train/                  |            |
# |    approx_kl            | 0.06447627 |
# |    clip_fraction        | 0.499      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -18.8      |
# |    explained_variance   | -3.58e-07  |
# |    learning_rate        | 0.0421     |
# |    loss                 | 50         |
# |    n_updates            | 210        |
# |    policy_gradient_loss | 0.0159     |
# |    reward               | -1.0285001 |
# |    std                  | 2.87       |
# |    value_loss           | 109        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 132        |
# |    iterations           | 23         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 2944       |
# | train/                  |            |
# |    approx_kl            | 0.29716617 |
# |    clip_fraction        | 0.62       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -18.7      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0421     |
# |    loss                 | 78.7       |
# |    n_updates            | 220        |
# |    policy_gradient_loss | 0.0217     |
# |    reward               | 2.424222   |
# |    std                  | 2.91       |
# |    value_loss           | 151        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 24          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.08135905  |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18.8       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0421      |
# |    loss                 | 80.5        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00711    |
# |    reward               | -0.05036622 |
# |    std                  | 2.9         |
# |    value_loss           | 164         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 25          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 3200        |
# | train/                  |             |
# |    approx_kl            | 0.097025976 |
# |    clip_fraction        | 0.357       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18.7       |
# |    explained_variance   | -0.000378   |
# |    learning_rate        | 0.0421      |
# |    loss                 | 372         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00481    |
# |    reward               | 0.49112338  |
# |    std                  | 2.92        |
# |    value_loss           | 750         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 125          |
# |    iterations           | 26           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 3328         |
# | train/                  |              |
# |    approx_kl            | 1.7497487    |
# |    clip_fraction        | 0.744        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -18.8        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0421       |
# |    loss                 | 0.134        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 0.118        |
# |    reward               | -0.023162091 |
# |    std                  | 2.98         |
# |    value_loss           | 0.346        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 124          |
# |    iterations           | 27           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 3456         |
# | train/                  |              |
# |    approx_kl            | 0.19351402   |
# |    clip_fraction        | 0.602        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -19.1        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0421       |
# |    loss                 | 0.602        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 0.0274       |
# |    reward               | -0.073120125 |
# |    std                  | 3.13         |
# |    value_loss           | 1.77         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 124        |
# |    iterations           | 28         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 3584       |
# | train/                  |            |
# |    approx_kl            | 11.029698  |
# |    clip_fraction        | 0.866      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -19.3      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0421     |
# |    loss                 | 4.61       |
# |    n_updates            | 270        |
# |    policy_gradient_loss | 0.333      |
# |    reward               | -0.7564399 |
# |    std                  | 3.17       |
# |    value_loss           | 9.1        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 124        |
# |    iterations           | 29         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 3712       |
# | train/                  |            |
# |    approx_kl            | 1.6004982  |
# |    clip_fraction        | 0.698      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -19.6      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0421     |
# |    loss                 | 1.73       |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.12       |
# |    reward               | -0.5282774 |
# |    std                  | 3.51       |
# |    value_loss           | 3.49       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 30          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 3840        |
# | train/                  |             |
# |    approx_kl            | 0.30130908  |
# |    clip_fraction        | 0.701       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0421      |
# |    loss                 | 2.58        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.1         |
# |    reward               | 0.061587494 |
# |    std                  | 3.56        |
# |    value_loss           | 5.63        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 123       |
# |    iterations           | 31        |
# |    time_elapsed         | 32        |
# |    total_timesteps      | 3968      |
# | train/                  |           |
# |    approx_kl            | 7.995921  |
# |    clip_fraction        | 0.873     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -20.8     |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0421    |
# |    loss                 | 1.04      |
# |    n_updates            | 300       |
# |    policy_gradient_loss | 0.193     |
# |    reward               | -6.433978 |
# |    std                  | 3.76      |
# |    value_loss           | 2.43      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 124        |
# |    iterations           | 32         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.35250506 |
# |    clip_fraction        | 0.59       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -21.5      |
# |    explained_variance   | -2.23e-05  |
# |    learning_rate        | 0.0421     |
# |    loss                 | 6.78       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.0339     |
# |    reward               | 0.13382849 |
# |    std                  | 4.07       |
# |    value_loss           | 15.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 125        |
# |    iterations           | 33         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 4224       |
# | train/                  |            |
# |    approx_kl            | 0.21311969 |
# |    clip_fraction        | 0.471      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22        |
# |    explained_variance   | -4.65e-06  |
# |    learning_rate        | 0.0421     |
# |    loss                 | 12.5       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | 0.0383     |
# |    reward               | 0.28015485 |
# |    std                  | 4.2        |
# |    value_loss           | 25.2       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 124        |
# |    iterations           | 34         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 4352       |
# | train/                  |            |
# |    approx_kl            | 0.08132935 |
# |    clip_fraction        | 0.484      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.2      |
# |    explained_variance   | -0.0282    |
# |    learning_rate        | 0.0421     |
# |    loss                 | 12.6       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.03      |
# |    reward               | 0.2914084  |
# |    std                  | 4.33       |
# |    value_loss           | 27.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 124        |
# |    iterations           | 35         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 4480       |
# | train/                  |            |
# |    approx_kl            | 0.40135714 |
# |    clip_fraction        | 0.608      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.2      |
# |    explained_variance   | -0.299     |
# |    learning_rate        | 0.0421     |
# |    loss                 | 4.51       |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0271    |
# |    reward               | -0.9513367 |
# |    std                  | 4.3        |
# |    value_loss           | 12         |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 123        |
# |    iterations           | 36         |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 4608       |
# | train/                  |            |
# |    approx_kl            | 0.45809165 |
# |    clip_fraction        | 0.601      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.2      |
# |    explained_variance   | 0.000738   |
# |    learning_rate        | 0.0421     |
# |    loss                 | 4.65       |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.0066     |
# |    reward               | -1.871114  |
# |    std                  | 4.41       |
# |    value_loss           | 9.75       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 123        |
# |    iterations           | 37         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 4736       |
# | train/                  |            |
# |    approx_kl            | 1.5009999  |
# |    clip_fraction        | 0.805      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.6      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0421     |
# |    loss                 | 2.92       |
# |    n_updates            | 360        |
# |    policy_gradient_loss | 0.165      |
# |    reward               | 0.92784846 |
# |    std                  | 4.92       |
# |    value_loss           | 7.46       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 122        |
# |    iterations           | 38         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 4864       |
# | train/                  |            |
# |    approx_kl            | 0.07149001 |
# |    clip_fraction        | 0.368      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23        |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0421     |
# |    loss                 | 5.32       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0103    |
# |    reward               | 0.18578911 |
# |    std                  | 5.02       |
# |    value_loss           | 13.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 123        |
# |    iterations           | 39         |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 4992       |
# | train/                  |            |
# |    approx_kl            | 0.06681698 |
# |    clip_fraction        | 0.403      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23        |
# |    explained_variance   | 3.64e-06   |
# |    learning_rate        | 0.0421     |
# |    loss                 | 16.7       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.00826   |
# |    reward               | 4.3325515  |
# |    std                  | 5.2        |
# |    value_loss           | 34.2       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 123        |
# |    iterations           | 40         |
# |    time_elapsed         | 41         |
# |    total_timesteps      | 5120       |
# | train/                  |            |
# |    approx_kl            | 0.19071439 |
# |    clip_fraction        | 0.497      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.3      |
# |    explained_variance   | -3.1e-06   |
# |    learning_rate        | 0.0421     |
# |    loss                 | 13.2       |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.0209     |
# |    reward               | -3.9341788 |
# |    std                  | 5.3        |
# |    value_loss           | 28.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 41          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 5248        |
# | train/                  |             |
# |    approx_kl            | 0.029483998 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.3       |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.0421      |
# |    loss                 | 22.5        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0122     |
# |    reward               | -1.3911502  |
# |    std                  | 5.37        |
# |    value_loss           | 46.7        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 123        |
# |    iterations           | 42         |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 5376       |
# | train/                  |            |
# |    approx_kl            | 0.26983392 |
# |    clip_fraction        | 0.514      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.6      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0421     |
# |    loss                 | 9.95       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0246    |
# |    reward               | -0.5999761 |
# |    std                  | 5.75       |
# |    value_loss           | 22.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 43          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 5504        |
# | train/                  |             |
# |    approx_kl            | 0.6164999   |
# |    clip_fraction        | 0.667       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24         |
# |    explained_variance   | 3.58e-07    |
# |    learning_rate        | 0.0421      |
# |    loss                 | 10.6        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.0992      |
# |    reward               | -0.07629305 |
# |    std                  | 5.85        |
# |    value_loss           | 43.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 124        |
# |    iterations           | 44         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 5632       |
# | train/                  |            |
# |    approx_kl            | 0.07374951 |
# |    clip_fraction        | 0.357      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -24.1      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0421     |
# |    loss                 | 7.94       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.00978   |
# |    reward               | 1.7399682  |
# |    std                  | 5.79       |
# |    value_loss           | 18.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 45          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 5760        |
# | train/                  |             |
# |    approx_kl            | 0.014409363 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0421      |
# |    loss                 | 36.9        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00224    |
# |    reward               | 4.694677    |
# |    std                  | 5.83        |
# |    value_loss           | 90          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 46          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 5888        |
# | train/                  |             |
# |    approx_kl            | 0.16819601  |
# |    clip_fraction        | 0.455       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0421      |
# |    loss                 | 38.3        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0326     |
# |    reward               | -0.27598217 |
# |    std                  | 6.13        |
# |    value_loss           | 79.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 126        |
# |    iterations           | 47         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 6016       |
# | train/                  |            |
# |    approx_kl            | 0.3333221  |
# |    clip_fraction        | 0.355      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -24.6      |
# |    explained_variance   | -2.38e-07  |
# |    learning_rate        | 0.0421     |
# |    loss                 | 87.1       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | 0.0122     |
# |    reward               | 0.49160305 |
# |    std                  | 6.21       |
# |    value_loss           | 181        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 48          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.24000627  |
# |    clip_fraction        | 0.515       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0421      |
# |    loss                 | 64          |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00449    |
# |    reward               | -0.13584097 |
# |    std                  | 6.57        |
# |    value_loss           | 129         |
# -----------------------------------------
# ...
# |    iterations           | 53         |
# |    time_elapsed         | 1069       |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.08802983 |
# |    clip_fraction        | 0.467      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -40        |
# |    explained_variance   | 0.865      |
# |    learning_rate        | 0.0372     |
# |    loss                 | 1.97       |
# |    n_updates            | 520        |
# |    policy_gradient_loss | 0.0402     |
# |    reward               | 0.8698062  |
# |    std                  | 44.1       |
# |    value_loss           | 20.6       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 102        |
# |    iterations           | 54         |
# |    time_elapsed         | 1078       |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.17939846 |
# |    clip_fraction        | 0.408      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -40.2      |
# |    explained_variance   | 0.652      |
# |    learning_rate        | 0.0372     |
# |    loss                 | 1.61       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | 0.0309     |
# |    reward               | 0.11374792 |
# |    std                  | 44.8       |
# |    value_loss           | 78.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 55          |
# |    time_elapsed         | 1086        |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.020158472 |
# |    clip_fraction        | 0.495       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -40.6       |
# |    explained_variance   | 0.606       |
# |    learning_rate        | 0.0372      |
# |    loss                 | 16.2        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.0533      |
# |    reward               | 1.9646792   |
# |    std                  | 46.3        |
# |    value_loss           | 96.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 56          |
# |    time_elapsed         | 1096        |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.028064357 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -40.6       |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0372      |
# |    loss                 | 4.23        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | 0.00668     |
# |    reward               | 1.2570368   |
# |    std                  | 47.2        |
# |    value_loss           | 17.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 57           |
# |    time_elapsed         | 1104         |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.06949323   |
# |    clip_fraction        | 0.308        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -40.9        |
# |    explained_variance   | 0.669        |
# |    learning_rate        | 0.0372       |
# |    loss                 | 5.65         |
# |    n_updates            | 560          |
# |    policy_gradient_loss | 0.00607      |
# |    reward               | -0.086916685 |
# |    std                  | 49.2         |
# |    value_loss           | 76           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 58          |
# |    time_elapsed         | 1113        |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.020574337 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.635       |
# |    learning_rate        | 0.0372      |
# |    loss                 | 21.9        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | 0.00456     |
# |    reward               | -0.29812554 |
# |    std                  | 49.3        |
# |    value_loss           | 126         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 59          |
# |    time_elapsed         | 1122        |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.033621702 |
# |    clip_fraction        | 0.385       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0372      |
# |    loss                 | 0.715       |
# |    n_updates            | 580         |
# |    policy_gradient_loss | 0.0209      |
# |    reward               | 0.075398475 |
# |    std                  | 49.8        |
# |    value_loss           | 17.4        |
# -----------------------------------------
# day: 3060, episode: 340
# begin_total_asset: 1000000.00
# end_total_asset: 5843863.96
# total_reward: 4843863.96
# total_cost: 13944.07
# total_trades: 15973
# Sharpe: 0.970
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 60          |
# |    time_elapsed         | 1138        |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.013185241 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | 0.672       |
# |    learning_rate        | 0.0372      |
# |    loss                 | 6.32        |
# |    n_updates            | 590         |
# |    policy_gradient_loss | 0.00237     |
# |    reward               | -0.15430546 |
# |    std                  | 50.4        |
# |    value_loss           | 82.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 61          |
# |    time_elapsed         | 1148        |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.041831087 |
# |    clip_fraction        | 0.352       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 0.0372      |
# |    loss                 | 3.83        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | 0.00535     |
# |    reward               | 0.8061431   |
# |    std                  | 51.4        |
# |    value_loss           | 104         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 62          |
# |    time_elapsed         | 1157        |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.010724747 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | 0.881       |
# |    learning_rate        | 0.0372      |
# |    loss                 | 5.03        |
# |    n_updates            | 610         |
# |    policy_gradient_loss | 0.0142      |
# |    reward               | 1.3609204   |
# |    std                  | 52.4        |
# |    value_loss           | 20.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 110        |
# |    iterations           | 63         |
# |    time_elapsed         | 1167       |
# |    total_timesteps      | 129024     |
# | train/                  |            |
# |    approx_kl            | 0.05687416 |
# |    clip_fraction        | 0.292      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.9      |
# |    explained_variance   | 0.69       |
# |    learning_rate        | 0.0372     |
# |    loss                 | 43.5       |
# |    n_updates            | 620        |
# |    policy_gradient_loss | 0.00675    |
# |    reward               | -0.7689809 |
# |    std                  | 51.6       |
# |    value_loss           | 76.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 64          |
# |    time_elapsed         | 1176        |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.023868637 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.68        |
# |    learning_rate        | 0.0372      |
# |    loss                 | 51.4        |
# |    n_updates            | 630         |
# |    policy_gradient_loss | 0.0147      |
# |    reward               | -1.9404842  |
# |    std                  | 52.5        |
# |    value_loss           | 99.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 65          |
# |    time_elapsed         | 1185        |
# |    total_timesteps      | 133120      |
# | train/                  |             |
# |    approx_kl            | 0.019785436 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0372      |
# |    loss                 | 6.39        |
# |    n_updates            | 640         |
# |    policy_gradient_loss | 0.00838     |
# |    reward               | -1.2824119  |
# |    std                  | 52.6        |
# |    value_loss           | 21.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 66          |
# |    time_elapsed         | 1196        |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.03130955  |
# |    clip_fraction        | 0.335       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.703       |
# |    learning_rate        | 0.0372      |
# |    loss                 | 507         |
# |    n_updates            | 650         |
# |    policy_gradient_loss | 0.0109      |
# |    reward               | -0.19961514 |
# |    std                  | 52.3        |
# |    value_loss           | 89.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 67          |
# |    time_elapsed         | 1207        |
# |    total_timesteps      | 137216      |
# | train/                  |             |
# |    approx_kl            | 0.038817957 |
# |    clip_fraction        | 0.362       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.665       |
# |    learning_rate        | 0.0372      |
# |    loss                 | 12.6        |
# |    n_updates            | 660         |
# |    policy_gradient_loss | 0.0103      |
# |    reward               | 1.015645    |
# |    std                  | 54.4        |
# |    value_loss           | 94.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 68          |
# |    time_elapsed         | 1221        |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.056741893 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0372      |
# |    loss                 | 15.7        |
# |    n_updates            | 670         |
# |    policy_gradient_loss | 0.00962     |
# |    reward               | 1.8469145   |
# |    std                  | 55.2        |
# |    value_loss           | 20.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 69          |
# |    time_elapsed         | 1239        |
# |    total_timesteps      | 141312      |
# | train/                  |             |
# |    approx_kl            | 0.019602964 |
# |    clip_fraction        | 0.389       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0372      |
# |    loss                 | 55.9        |
# |    n_updates            | 680         |
# |    policy_gradient_loss | 0.00706     |
# |    reward               | 0.18152463  |
# |    std                  | 55.3        |
# |    value_loss           | 98.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 70          |
# |    time_elapsed         | 1259        |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.011642368 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | 0.669       |
# |    learning_rate        | 0.0372      |
# |    loss                 | 28          |
# |    n_updates            | 690         |
# |    policy_gradient_loss | 0.000655    |
# |    reward               | 8.629734    |
# |    std                  | 55.9        |
# |    value_loss           | 96.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 71          |
# |    time_elapsed         | 1278        |
# |    total_timesteps      | 145408      |
# | train/                  |             |
# |    approx_kl            | 0.009428284 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0372      |
# |    loss                 | 14.5        |
# |    n_updates            | 700         |
# |    policy_gradient_loss | 0.00695     |
# |    reward               | 0.08635752  |
# |    std                  | 55.7        |
# |    value_loss           | 26.9        |
# -----------------------------------------

# %%
print(perf_stats_all)
# Out:
#                             0
# Annual return        0.021349
# Cumulative returns   0.039661
# Annual volatility    0.066063
# Sharpe ratio         0.353407
# Calmar ratio         0.201586
# Stability            0.425234
# Max drawdown        -0.105903
# Omega ratio          1.070212
# Sortino ratio        0.517351
# Skew                      NaN
# Kurtosis                  NaN
# Tail ratio           1.169491
# Daily value at risk -0.008231

# %%
#trading
# Out:
# hit end!
#            date  account_value
# 459  2021-12-23   1.140401e+06
# 460  2021-12-27   1.151409e+06
# 461  2021-12-28   1.153059e+06
# 462  2021-12-29   1.153755e+06
# 463  2021-12-30   1.151230e+06
#             AAPL  CAT  DIS  GS  INTC  JPM  MMM  MSFT
# date
# 2021-03-17     4    0    3   0     0    0    2     1
# 2021-03-18     4    0    3   0     0    0    2     1
# 2021-03-19     4    0    3   0     0    0    2     1
# 2021-03-22     4    0    3   0     0    0    2     1
# 2021-03-23     4    0    3   0     0    0    2     1
# ...          ...  ...  ...  ..   ...  ...  ...   ...
# 2021-12-22     4    0    3   0     0    0    2     1
# 2021-12-23     4    0    3   0     0    0    2     1
# 2021-12-27     4    0    3   0     0    0    2     1
# 2021-12-28     4    0    3   0     0    0    2     1
# 2021-12-29     4    0    3   0     0    0    2     1
#
# [200 rows x 8 columns]

# %%
#Backtesting Results
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
perf_stats_all.to_csv("./"+RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return          0.079487
# Cumulative returns     0.151230
# Annual volatility      0.063709
# Sharpe ratio           1.235131
# Calmar ratio           1.649271
# Stability              0.929493
# Max drawdown          -0.048195
# Omega ratio            1.263219
# Sortino ratio          1.801034
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.026593
# Daily value at risk   -0.007714
# dtype: float64

# %%
#df_actions.to_csv('action_ppo_s(h20)3.csv')

# %%
#a = perf_stats_all.to_dict()
#wandb.save(perf_stats_all)
#wandb.save(df_actions)
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# Synced <strong style="color:#cdcd00">magic-microwave-5</strong>: <a href="https://wandb.ai/finsrl/test-project/runs/1iohx6rl" target="_blank">https://wandb.ai/finsrl/test-project/runs/1iohx6rl</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_195214-1iohx6rl/logs</code>
